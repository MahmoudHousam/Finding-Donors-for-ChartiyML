# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format= 'retina'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch import optim
import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import workspace_utils, train, predict
import os, random
import json
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {'train_transforms':transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
]),
                  'valid_test_transforms':transforms.Compose([
                      transforms.Resize(225),
                      transforms.CenterCrop(224),
                      transforms.ToTensor(),
                      transforms.Normalize([0.485, 0.456, 0.406],
                                           [0.229, 0.224, 0.225])
                  ])}

# TODO: Load the datasets with ImageFolder
image_datasets = {'train_data':datasets.ImageFolder(train_dir, transform= data_transforms['train_transforms']),
                  'valid_data':datasets.ImageFolder(valid_dir, transform= data_transforms['valid_test_transforms']),
                  'test_data':datasets.ImageFolder(test_dir, transform= data_transforms['valid_test_transforms'])}

# TODO: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {'train_loader':torch.utils.data.DataLoader(image_datasets['train_data'], batch_size= 64, shuffle= True),
               'valid_loader':torch.utils.data.DataLoader(image_datasets['valid_data'], batch_size= 32),
               'test_loader':torch.utils.data.DataLoader(image_datasets['test_data'], batch_size= 32)}

# %%
images, labels= next(iter(dataloaders['test_loader']))
images.shape, labels.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32]))

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %% [markdown]
# ## Build and train your network

# %%
# importing a pretrained networ
model= models.vgg16(pretrained=True) 
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 95064320.91it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# freezing model's parameters
for paramerter in model.parameters():
    paramerter.requires_grad= False

# %%
# building the new classifier
classifier= nn.Sequential(nn.Linear(25088,4096),
                          nn.ReLU(),
                          nn.Dropout(p=0.3),
                          nn.Linear(4096, 4096),
                          nn.ReLU(),
                          nn.Dropout(p=0.3),
                          nn.Linear(4096,1000),
                          nn.ReLU(),
                          nn.Dropout(0.3),
                          nn.Linear(1000,102),
                          nn.LogSoftmax(dim=1))
model.classifier= classifier
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.3)
#     (9): Linear(in_features=1000, out_features=102, bias=True)
#     (10): LogSoftmax()
#   )
# )

# %%
# passing the model to GPU
device= torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model= model.to(device)

# %%
# initializing loss function and optimizer
criterion= nn.NLLLoss()
optimizer= optim.Adam(model.classifier.parameters(), lr=0.001)
epochs= 12
steps= 0
training_loss= 0
print_every= 5

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# building the network
from workspace_utils import active_session
with active_session():
    for epoch in range(epochs):
        #train the model
        for images, labels in dataloaders['train_loader']:
            steps += 1
            images, labels= images.to(device), labels.to(device) #passing images & labels to GPU
            optimizer.zero_grad() #clears the last gradients from the last step
            train_output= model.forward(images) #forwarding images to the model
            tr_loss= criterion(train_output, labels) #calculating the error function
            tr_loss.backward() #computes the derivatives of the loss using backprobagation
            optimizer.step() #telling the optimizer to take a step based on the gradients of the parameters
            training_loss += tr_loss.item() #calculating the training loss
            if steps % print_every == 0:
                testing_loss= 0
                accuracy= 0
                model.eval()
                with torch.no_grad():
                        #test the model
                        for images, labels in dataloaders['valid_loader']:
                            images, labels= images.to(device), labels.to(device)
                            test_output= model.forward(images)
                            test_loss= criterion(test_output, labels)
                            testing_loss += test_loss.item()
                            #getting accuracy
                            ps= torch.exp(test_output)
                            top_p, top_class= ps.topk(1, dim=1)
                            equal= top_class == labels.view(*top_class.shape)
                            accuracy += torch.mean(equal.type(torch.FloatTensor)).item()
                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {training_loss/steps:.3f}.. "
                      f"Test loss: {testing_loss/len(dataloaders['valid_loader']):.3f}.."
                      f"Test accuracy: {accuracy/len(dataloaders['valid_loader']):.3f}")
                model.train()
# Out:
# Epoch 1/12.. Train loss: 5.075.. Test loss: 4.618..Test accuracy: 0.016
# Epoch 1/12.. Train loss: 4.848.. Test loss: 4.542..Test accuracy: 0.025
# Epoch 1/12.. Train loss: 4.734.. Test loss: 4.443..Test accuracy: 0.048
# Epoch 1/12.. Train loss: 4.662.. Test loss: 4.287..Test accuracy: 0.066
# Epoch 1/12.. Train loss: 4.578.. Test loss: 4.023..Test accuracy: 0.143
# Epoch 1/12.. Train loss: 4.490.. Test loss: 3.769..Test accuracy: 0.165
# Epoch 1/12.. Train loss: 4.397.. Test loss: 3.668..Test accuracy: 0.163
# Epoch 1/12.. Train loss: 4.314.. Test loss: 3.451..Test accuracy: 0.206
# Epoch 1/12.. Train loss: 4.238.. Test loss: 3.155..Test accuracy: 0.249
# Epoch 1/12.. Train loss: 4.153.. Test loss: 2.873..Test accuracy: 0.308
# Epoch 1/12.. Train loss: 4.072.. Test loss: 2.662..Test accuracy: 0.322
# Epoch 1/12.. Train loss: 3.984.. Test loss: 2.564..Test accuracy: 0.343
# Epoch 1/12.. Train loss: 3.895.. Test loss: 2.460..Test accuracy: 0.387
# Epoch 1/12.. Train loss: 3.816.. Test loss: 2.235..Test accuracy: 0.415
# Epoch 1/12.. Train loss: 3.749.. Test loss: 2.142..Test accuracy: 0.429
# Epoch 1/12.. Train loss: 3.674.. Test loss: 2.131..Test accuracy: 0.444
# Epoch 1/12.. Train loss: 3.613.. Test loss: 2.127..Test accuracy: 0.444
# Epoch 1/12.. Train loss: 3.561.. Test loss: 1.888..Test accuracy: 0.479
# Epoch 1/12.. Train loss: 3.506.. Test loss: 1.851..Test accuracy: 0.510
# Epoch 1/12.. Train loss: 3.445.. Test loss: 1.831..Test accuracy: 0.529
# Epoch 2/12.. Train loss: 3.386.. Test loss: 1.956..Test accuracy: 0.484
# Epoch 2/12.. Train loss: 3.327.. Test loss: 1.701..Test accuracy: 0.556
# Epoch 2/12.. Train loss: 3.278.. Test loss: 1.833..Test accuracy: 0.509
# Epoch 2/12.. Train loss: 3.231.. Test loss: 1.647..Test accuracy: 0.556
# Epoch 2/12.. Train loss: 3.181.. Test loss: 1.679..Test accuracy: 0.549
# Epoch 2/12.. Train loss: 3.135.. Test loss: 1.497..Test accuracy: 0.567
# Epoch 2/12.. Train loss: 3.094.. Test loss: 1.588..Test accuracy: 0.549
# Epoch 2/12.. Train loss: 3.055.. Test loss: 1.499..Test accuracy: 0.576
# Epoch 2/12.. Train loss: 3.014.. Test loss: 1.522..Test accuracy: 0.582
# Epoch 2/12.. Train loss: 2.981.. Test loss: 1.546..Test accuracy: 0.576
# Epoch 2/12.. Train loss: 2.949.. Test loss: 1.510..Test accuracy: 0.564
# Epoch 2/12.. Train loss: 2.916.. Test loss: 1.547..Test accuracy: 0.575
# Epoch 2/12.. Train loss: 2.889.. Test loss: 1.531..Test accuracy: 0.587
# Epoch 2/12.. Train loss: 2.857.. Test loss: 1.340..Test accuracy: 0.630
# Epoch 2/12.. Train loss: 2.833.. Test loss: 1.341..Test accuracy: 0.627
# Epoch 2/12.. Train loss: 2.805.. Test loss: 1.304..Test accuracy: 0.628
# Epoch 2/12.. Train loss: 2.779.. Test loss: 1.371..Test accuracy: 0.608
# Epoch 2/12.. Train loss: 2.761.. Test loss: 1.229..Test accuracy: 0.675
# Epoch 2/12.. Train loss: 2.738.. Test loss: 1.244..Test accuracy: 0.676
# Epoch 2/12.. Train loss: 2.714.. Test loss: 1.241..Test accuracy: 0.659
# Epoch 2/12.. Train loss: 2.694.. Test loss: 1.160..Test accuracy: 0.668
# Epoch 3/12.. Train loss: 2.669.. Test loss: 1.121..Test accuracy: 0.675
# Epoch 3/12.. Train loss: 2.643.. Test loss: 1.192..Test accuracy: 0.661
# Epoch 3/12.. Train loss: 2.619.. Test loss: 1.163..Test accuracy: 0.667
# Epoch 3/12.. Train loss: 2.602.. Test loss: 1.273..Test accuracy: 0.662
# Epoch 3/12.. Train loss: 2.581.. Test loss: 1.201..Test accuracy: 0.661
# Epoch 3/12.. Train loss: 2.564.. Test loss: 1.186..Test accuracy: 0.678
# Epoch 3/12.. Train loss: 2.546.. Test loss: 1.212..Test accuracy: 0.650
# Epoch 3/12.. Train loss: 2.530.. Test loss: 1.116..Test accuracy: 0.687
# Epoch 3/12.. Train loss: 2.510.. Test loss: 1.102..Test accuracy: 0.707
# Epoch 3/12.. Train loss: 2.495.. Test loss: 1.068..Test accuracy: 0.714
# Epoch 3/12.. Train loss: 2.478.. Test loss: 1.032..Test accuracy: 0.711
# Epoch 3/12.. Train loss: 2.464.. Test loss: 1.041..Test accuracy: 0.721
# Epoch 3/12.. Train loss: 2.446.. Test loss: 1.063..Test accuracy: 0.714
# Epoch 3/12.. Train loss: 2.430.. Test loss: 0.972..Test accuracy: 0.732
# Epoch 3/12.. Train loss: 2.416.. Test loss: 1.000..Test accuracy: 0.717
# Epoch 3/12.. Train loss: 2.403.. Test loss: 1.105..Test accuracy: 0.700
# Epoch 3/12.. Train loss: 2.389.. Test loss: 1.051..Test accuracy: 0.732
# Epoch 3/12.. Train loss: 2.375.. Test loss: 0.956..Test accuracy: 0.743
# Epoch 3/12.. Train loss: 2.362.. Test loss: 0.999..Test accuracy: 0.728
# Epoch 3/12.. Train loss: 2.349.. Test loss: 1.030..Test accuracy: 0.732
# Epoch 4/12.. Train loss: 2.337.. Test loss: 0.947..Test accuracy: 0.728
# Epoch 4/12.. Train loss: 2.324.. Test loss: 0.971..Test accuracy: 0.724
# Epoch 4/12.. Train loss: 2.310.. Test loss: 0.981..Test accuracy: 0.719
# Epoch 4/12.. Train loss: 2.294.. Test loss: 1.009..Test accuracy: 0.711
# Epoch 4/12.. Train loss: 2.283.. Test loss: 0.912..Test accuracy: 0.732
# Epoch 4/12.. Train loss: 2.270.. Test loss: 1.021..Test accuracy: 0.707
# Epoch 4/12.. Train loss: 2.258.. Test loss: 1.004..Test accuracy: 0.716
# Epoch 4/12.. Train loss: 2.247.. Test loss: 0.990..Test accuracy: 0.724
# Epoch 4/12.. Train loss: 2.238.. Test loss: 0.921..Test accuracy: 0.761
# Epoch 4/12.. Train loss: 2.229.. Test loss: 0.915..Test accuracy: 0.759
# Epoch 4/12.. Train loss: 2.214.. Test loss: 0.957..Test accuracy: 0.740
# Epoch 4/12.. Train loss: 2.204.. Test loss: 0.914..Test accuracy: 0.727
# Epoch 4/12.. Train loss: 2.192.. Test loss: 0.971..Test accuracy: 0.721
# Epoch 4/12.. Train loss: 2.183.. Test loss: 0.944..Test accuracy: 0.742
# Epoch 4/12.. Train loss: 2.175.. Test loss: 0.850..Test accuracy: 0.779
# Epoch 4/12.. Train loss: 2.165.. Test loss: 0.878..Test accuracy: 0.747
# Epoch 4/12.. Train loss: 2.156.. Test loss: 0.913..Test accuracy: 0.734
# Epoch 4/12.. Train loss: 2.148.. Test loss: 0.856..Test accuracy: 0.762
# Epoch 4/12.. Train loss: 2.139.. Test loss: 0.918..Test accuracy: 0.725
# Epoch 4/12.. Train loss: 2.130.. Test loss: 0.862..Test accuracy: 0.762
# Epoch 4/12.. Train loss: 2.120.. Test loss: 0.853..Test accuracy: 0.757
# Epoch 5/12.. Train loss: 2.112.. Test loss: 1.049..Test accuracy: 0.720
# Epoch 5/12.. Train loss: 2.104.. Test loss: 0.917..Test accuracy: 0.760
# Epoch 5/12.. Train loss: 2.094.. Test loss: 0.874..Test accuracy: 0.743
# Epoch 5/12.. Train loss: 2.088.. Test loss: 0.844..Test accuracy: 0.772
# Epoch 5/12.. Train loss: 2.081.. Test loss: 0.800..Test accuracy: 0.791
# Epoch 5/12.. Train loss: 2.072.. Test loss: 0.762..Test accuracy: 0.784
# Epoch 5/12.. Train loss: 2.063.. Test loss: 0.862..Test accuracy: 0.772
# Epoch 5/12.. Train loss: 2.055.. Test loss: 0.810..Test accuracy: 0.772
# Epoch 5/12.. Train loss: 2.047.. Test loss: 0.859..Test accuracy: 0.764
# Epoch 5/12.. Train loss: 2.040.. Test loss: 0.866..Test accuracy: 0.765
# Epoch 5/12.. Train loss: 2.031.. Test loss: 0.858..Test accuracy: 0.761
# Epoch 5/12.. Train loss: 2.021.. Test loss: 0.749..Test accuracy: 0.812
# Epoch 5/12.. Train loss: 2.015.. Test loss: 0.754..Test accuracy: 0.803
# Epoch 5/12.. Train loss: 2.007.. Test loss: 0.832..Test accuracy: 0.769
# Epoch 5/12.. Train loss: 2.001.. Test loss: 0.723..Test accuracy: 0.785
# Epoch 5/12.. Train loss: 1.994.. Test loss: 0.711..Test accuracy: 0.800
# Epoch 5/12.. Train loss: 1.986.. Test loss: 0.820..Test accuracy: 0.766
# Epoch 5/12.. Train loss: 1.980.. Test loss: 0.827..Test accuracy: 0.789
# Epoch 5/12.. Train loss: 1.972.. Test loss: 0.795..Test accuracy: 0.787
# Epoch 5/12.. Train loss: 1.965.. Test loss: 0.710..Test accuracy: 0.803
# Epoch 5/12.. Train loss: 1.960.. Test loss: 0.663..Test accuracy: 0.820
# Epoch 6/12.. Train loss: 1.954.. Test loss: 0.733..Test accuracy: 0.813
# Epoch 6/12.. Train loss: 1.949.. Test loss: 0.787..Test accuracy: 0.796
# Epoch 6/12.. Train loss: 1.943.. Test loss: 0.770..Test accuracy: 0.784
# Epoch 6/12.. Train loss: 1.935.. Test loss: 0.694..Test accuracy: 0.810
# Epoch 6/12.. Train loss: 1.929.. Test loss: 0.719..Test accuracy: 0.818
# Epoch 6/12.. Train loss: 1.921.. Test loss: 0.747..Test accuracy: 0.810
# Epoch 6/12.. Train loss: 1.915.. Test loss: 0.697..Test accuracy: 0.819
# Epoch 6/12.. Train loss: 1.908.. Test loss: 0.665..Test accuracy: 0.815
# Epoch 6/12.. Train loss: 1.901.. Test loss: 0.686..Test accuracy: 0.813
# Epoch 6/12.. Train loss: 1.894.. Test loss: 0.748..Test accuracy: 0.797
# Epoch 6/12.. Train loss: 1.889.. Test loss: 0.745..Test accuracy: 0.799
# Epoch 6/12.. Train loss: 1.884.. Test loss: 0.682..Test accuracy: 0.824
# Epoch 6/12.. Train loss: 1.880.. Test loss: 0.633..Test accuracy: 0.824
# Epoch 6/12.. Train loss: 1.874.. Test loss: 0.712..Test accuracy: 0.806
# Epoch 6/12.. Train loss: 1.868.. Test loss: 0.680..Test accuracy: 0.808
# Epoch 6/12.. Train loss: 1.862.. Test loss: 0.696..Test accuracy: 0.800
# Epoch 6/12.. Train loss: 1.857.. Test loss: 0.679..Test accuracy: 0.807
# Epoch 6/12.. Train loss: 1.850.. Test loss: 0.669..Test accuracy: 0.810
# Epoch 6/12.. Train loss: 1.845.. Test loss: 0.656..Test accuracy: 0.822
# Epoch 6/12.. Train loss: 1.839.. Test loss: 0.650..Test accuracy: 0.812
# Epoch 7/12.. Train loss: 1.834.. Test loss: 0.704..Test accuracy: 0.812
# Epoch 7/12.. Train loss: 1.829.. Test loss: 0.761..Test accuracy: 0.798
# Epoch 7/12.. Train loss: 1.825.. Test loss: 0.751..Test accuracy: 0.801
# Epoch 7/12.. Train loss: 1.821.. Test loss: 0.747..Test accuracy: 0.795
# Epoch 7/12.. Train loss: 1.815.. Test loss: 0.733..Test accuracy: 0.804
# Epoch 7/12.. Train loss: 1.811.. Test loss: 0.722..Test accuracy: 0.812
# Epoch 7/12.. Train loss: 1.807.. Test loss: 0.732..Test accuracy: 0.807
# Epoch 7/12.. Train loss: 1.804.. Test loss: 0.723..Test accuracy: 0.800
# Epoch 7/12.. Train loss: 1.799.. Test loss: 0.638..Test accuracy: 0.835
# Epoch 7/12.. Train loss: 1.794.. Test loss: 0.654..Test accuracy: 0.811
# Epoch 7/12.. Train loss: 1.790.. Test loss: 0.690..Test accuracy: 0.807
# Epoch 7/12.. Train loss: 1.786.. Test loss: 0.744..Test accuracy: 0.796
# Epoch 7/12.. Train loss: 1.781.. Test loss: 0.688..Test accuracy: 0.824
# Epoch 7/12.. Train loss: 1.776.. Test loss: 0.659..Test accuracy: 0.827
# Epoch 7/12.. Train loss: 1.772.. Test loss: 0.624..Test accuracy: 0.839
# Epoch 7/12.. Train loss: 1.766.. Test loss: 0.618..Test accuracy: 0.841
# Epoch 7/12.. Train loss: 1.761.. Test loss: 0.567..Test accuracy: 0.848
# Epoch 7/12.. Train loss: 1.756.. Test loss: 0.541..Test accuracy: 0.850
# Epoch 7/12.. Train loss: 1.751.. Test loss: 0.552..Test accuracy: 0.846
# Epoch 7/12.. Train loss: 1.747.. Test loss: 0.622..Test accuracy: 0.838
# Epoch 7/12.. Train loss: 1.745.. Test loss: 0.690..Test accuracy: 0.818
# Epoch 8/12.. Train loss: 1.740.. Test loss: 0.717..Test accuracy: 0.820
# Epoch 8/12.. Train loss: 1.735.. Test loss: 0.724..Test accuracy: 0.820
# Epoch 8/12.. Train loss: 1.730.. Test loss: 0.692..Test accuracy: 0.823
# Epoch 8/12.. Train loss: 1.728.. Test loss: 0.654..Test accuracy: 0.827
# Epoch 8/12.. Train loss: 1.724.. Test loss: 0.649..Test accuracy: 0.824
# Epoch 8/12.. Train loss: 1.719.. Test loss: 0.615..Test accuracy: 0.847
# Epoch 8/12.. Train loss: 1.715.. Test loss: 0.610..Test accuracy: 0.833
# Epoch 8/12.. Train loss: 1.711.. Test loss: 0.670..Test accuracy: 0.823
# Epoch 8/12.. Train loss: 1.707.. Test loss: 0.743..Test accuracy: 0.815
# Epoch 8/12.. Train loss: 1.704.. Test loss: 0.656..Test accuracy: 0.836
# Epoch 8/12.. Train loss: 1.701.. Test loss: 0.708..Test accuracy: 0.824
# Epoch 8/12.. Train loss: 1.698.. Test loss: 0.733..Test accuracy: 0.816
# Epoch 8/12.. Train loss: 1.694.. Test loss: 0.703..Test accuracy: 0.810
# Epoch 8/12.. Train loss: 1.691.. Test loss: 0.701..Test accuracy: 0.811
# Epoch 8/12.. Train loss: 1.687.. Test loss: 0.645..Test accuracy: 0.840
# Epoch 8/12.. Train loss: 1.684.. Test loss: 0.686..Test accuracy: 0.836
# Epoch 8/12.. Train loss: 1.680.. Test loss: 0.720..Test accuracy: 0.818
# Epoch 8/12.. Train loss: 1.677.. Test loss: 0.695..Test accuracy: 0.830
# Epoch 8/12.. Train loss: 1.674.. Test loss: 0.735..Test accuracy: 0.815
# Epoch 8/12.. Train loss: 1.671.. Test loss: 0.696..Test accuracy: 0.824
# Epoch 9/12.. Train loss: 1.666.. Test loss: 0.719..Test accuracy: 0.837
# Epoch 9/12.. Train loss: 1.663.. Test loss: 0.743..Test accuracy: 0.811
# Epoch 9/12.. Train loss: 1.660.. Test loss: 0.737..Test accuracy: 0.816
# Epoch 9/12.. Train loss: 1.657.. Test loss: 0.759..Test accuracy: 0.815
# Epoch 9/12.. Train loss: 1.654.. Test loss: 0.740..Test accuracy: 0.824
# Epoch 9/12.. Train loss: 1.651.. Test loss: 0.702..Test accuracy: 0.833
# Epoch 9/12.. Train loss: 1.648.. Test loss: 0.655..Test accuracy: 0.842
# Epoch 9/12.. Train loss: 1.645.. Test loss: 0.682..Test accuracy: 0.829
# Epoch 9/12.. Train loss: 1.642.. Test loss: 0.693..Test accuracy: 0.830
# Epoch 9/12.. Train loss: 1.640.. Test loss: 0.677..Test accuracy: 0.837
# Epoch 9/12.. Train loss: 1.636.. Test loss: 0.707..Test accuracy: 0.827
# Epoch 9/12.. Train loss: 1.633.. Test loss: 0.707..Test accuracy: 0.824
# Epoch 9/12.. Train loss: 1.631.. Test loss: 0.645..Test accuracy: 0.838
# Epoch 9/12.. Train loss: 1.628.. Test loss: 0.657..Test accuracy: 0.825
# Epoch 9/12.. Train loss: 1.625.. Test loss: 0.682..Test accuracy: 0.833
# Epoch 9/12.. Train loss: 1.623.. Test loss: 0.684..Test accuracy: 0.843
# Epoch 9/12.. Train loss: 1.619.. Test loss: 0.694..Test accuracy: 0.839
# Epoch 9/12.. Train loss: 1.616.. Test loss: 0.644..Test accuracy: 0.845
# Epoch 9/12.. Train loss: 1.613.. Test loss: 0.635..Test accuracy: 0.854
# Epoch 9/12.. Train loss: 1.609.. Test loss: 0.619..Test accuracy: 0.859
# Epoch 9/12.. Train loss: 1.607.. Test loss: 0.684..Test accuracy: 0.830
# Epoch 10/12.. Train loss: 1.604.. Test loss: 0.725..Test accuracy: 0.818
# Epoch 10/12.. Train loss: 1.601.. Test loss: 0.700..Test accuracy: 0.833
# Epoch 10/12.. Train loss: 1.598.. Test loss: 0.691..Test accuracy: 0.832
# Epoch 10/12.. Train loss: 1.595.. Test loss: 0.638..Test accuracy: 0.846
# Epoch 10/12.. Train loss: 1.593.. Test loss: 0.584..Test accuracy: 0.860
# Epoch 10/12.. Train loss: 1.591.. Test loss: 0.599..Test accuracy: 0.849
# Epoch 10/12.. Train loss: 1.590.. Test loss: 0.621..Test accuracy: 0.851
# Epoch 10/12.. Train loss: 1.588.. Test loss: 0.622..Test accuracy: 0.842
# Epoch 10/12.. Train loss: 1.586.. Test loss: 0.607..Test accuracy: 0.845
# Epoch 10/12.. Train loss: 1.584.. Test loss: 0.637..Test accuracy: 0.850
# Epoch 10/12.. Train loss: 1.582.. Test loss: 0.643..Test accuracy: 0.840
# Epoch 10/12.. Train loss: 1.580.. Test loss: 0.620..Test accuracy: 0.833
# Epoch 10/12.. Train loss: 1.577.. Test loss: 0.644..Test accuracy: 0.832
# Epoch 10/12.. Train loss: 1.574.. Test loss: 0.645..Test accuracy: 0.828
# Epoch 10/12.. Train loss: 1.571.. Test loss: 0.638..Test accuracy: 0.826
# Epoch 10/12.. Train loss: 1.569.. Test loss: 0.660..Test accuracy: 0.841
# Epoch 10/12.. Train loss: 1.566.. Test loss: 0.699..Test accuracy: 0.834
# Epoch 10/12.. Train loss: 1.563.. Test loss: 0.714..Test accuracy: 0.817
# Epoch 10/12.. Train loss: 1.562.. Test loss: 0.687..Test accuracy: 0.818
# Epoch 10/12.. Train loss: 1.560.. Test loss: 0.705..Test accuracy: 0.827
# Epoch 10/12.. Train loss: 1.559.. Test loss: 0.666..Test accuracy: 0.822
# Epoch 11/12.. Train loss: 1.556.. Test loss: 0.662..Test accuracy: 0.826
# Epoch 11/12.. Train loss: 1.554.. Test loss: 0.691..Test accuracy: 0.818
# Epoch 11/12.. Train loss: 1.552.. Test loss: 0.642..Test accuracy: 0.834
# Epoch 11/12.. Train loss: 1.550.. Test loss: 0.619..Test accuracy: 0.840
# Epoch 11/12.. Train loss: 1.547.. Test loss: 0.635..Test accuracy: 0.839
# Epoch 11/12.. Train loss: 1.544.. Test loss: 0.588..Test accuracy: 0.851
# Epoch 11/12.. Train loss: 1.542.. Test loss: 0.560..Test accuracy: 0.864
# Epoch 11/12.. Train loss: 1.539.. Test loss: 0.617..Test accuracy: 0.840
# Epoch 11/12.. Train loss: 1.538.. Test loss: 0.711..Test accuracy: 0.829
# Epoch 11/12.. Train loss: 1.536.. Test loss: 0.652..Test accuracy: 0.834
# Epoch 11/12.. Train loss: 1.534.. Test loss: 0.586..Test accuracy: 0.845
# Epoch 11/12.. Train loss: 1.533.. Test loss: 0.590..Test accuracy: 0.838
# Epoch 11/12.. Train loss: 1.531.. Test loss: 0.605..Test accuracy: 0.841
# Epoch 11/12.. Train loss: 1.528.. Test loss: 0.655..Test accuracy: 0.842
# Epoch 11/12.. Train loss: 1.527.. Test loss: 0.677..Test accuracy: 0.833
# Epoch 11/12.. Train loss: 1.526.. Test loss: 0.622..Test accuracy: 0.851
# Epoch 11/12.. Train loss: 1.524.. Test loss: 0.625..Test accuracy: 0.855
# Epoch 11/12.. Train loss: 1.521.. Test loss: 0.665..Test accuracy: 0.844
# Epoch 11/12.. Train loss: 1.519.. Test loss: 0.632..Test accuracy: 0.862
# Epoch 11/12.. Train loss: 1.517.. Test loss: 0.664..Test accuracy: 0.846
# Epoch 12/12.. Train loss: 1.515.. Test loss: 0.630..Test accuracy: 0.855
# Epoch 12/12.. Train loss: 1.512.. Test loss: 0.606..Test accuracy: 0.846
# Epoch 12/12.. Train loss: 1.510.. Test loss: 0.598..Test accuracy: 0.843
# Epoch 12/12.. Train loss: 1.507.. Test loss: 0.606..Test accuracy: 0.848
# Epoch 12/12.. Train loss: 1.505.. Test loss: 0.611..Test accuracy: 0.853
# Epoch 12/12.. Train loss: 1.503.. Test loss: 0.612..Test accuracy: 0.859
# Epoch 12/12.. Train loss: 1.500.. Test loss: 0.639..Test accuracy: 0.837
# Epoch 12/12.. Train loss: 1.498.. Test loss: 0.652..Test accuracy: 0.842
# Epoch 12/12.. Train loss: 1.496.. Test loss: 0.637..Test accuracy: 0.847
# Epoch 12/12.. Train loss: 1.494.. Test loss: 0.578..Test accuracy: 0.860
# Epoch 12/12.. Train loss: 1.492.. Test loss: 0.584..Test accuracy: 0.858
# Epoch 12/12.. Train loss: 1.490.. Test loss: 0.586..Test accuracy: 0.865
# Epoch 12/12.. Train loss: 1.489.. Test loss: 0.625..Test accuracy: 0.853
# Epoch 12/12.. Train loss: 1.487.. Test loss: 0.595..Test accuracy: 0.851
# Epoch 12/12.. Train loss: 1.486.. Test loss: 0.559..Test accuracy: 0.852
# Epoch 12/12.. Train loss: 1.484.. Test loss: 0.562..Test accuracy: 0.848
# Epoch 12/12.. Train loss: 1.482.. Test loss: 0.554..Test accuracy: 0.865
# Epoch 12/12.. Train loss: 1.479.. Test loss: 0.540..Test accuracy: 0.879
# Epoch 12/12.. Train loss: 1.478.. Test loss: 0.529..Test accuracy: 0.882
# Epoch 12/12.. Train loss: 1.476.. Test loss: 0.572..Test accuracy: 0.863
# Epoch 12/12.. Train loss: 1.474.. Test loss: 0.597..Test accuracy: 0.858

# %%
print("Training Loss Mean: {}".format(np.mean(training_loss/steps)))
print("Validation Loss Mean: {}".format(np.mean(testing_loss/len(dataloaders['valid_loader']))))
print("Model Accuracy: {}".format(np.mean(accuracy/len(dataloaders['valid_loader']))))
# Out:
# Training Loss Mean: 1.4738531909810686
# Validation Loss Mean: 0.5970662359434825
# Model Accuracy: 0.8584401699212881

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
checkpoint={
    'architecture': 'vgg16',
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'classifier': model.classifier,
    'class_label': image_datasets['train_data'].class_to_idx,
    'input_size': 25088,
    'output_size': 102,
    'learning_rate': 0.001,
    'batch_size': 64,
    'epochs': epochs
}
torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
def load_checkpoint(file):
    checkpoint= torch.load(file)
    model= getattr(torchvision.models, checkpoint['architecture'])(pretrained=True) #it returns the value of the named attribute of an object
    model.classifier = checkpoint['classifier']
    model.epochs = checkpoint['epochs']
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_idx = checkpoint['class_label']
    optimizer.load_state_dict(checkpoint['optimizer'])
    learning_rate = checkpoint['learning_rate']
    return model
model= load_checkpoint('checkpoint.pth')
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.3)
#     (9): Linear(in_features=1000, out_features=102, bias=True)
#     (10): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    pic= Image.open(image)
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
    pic_trnasform= transform(pic)
    pic_to_array= np.array(pic_trnasform)
    return pic_to_array

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
# Test image
image_name = data_dir + '/test' + '/1/' + 'image_06743.jpg'
img_test =  process_image(image_name)
# Check to see if image pre-processing was successful
imshow(img_test, ax=None, title=None)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    load_model= load_checkpoint(model).cpu()
    pic= process_image(image_path)
    pic_tensor= torch.from_numpy(pic).type(torch.FloatTensor)
    pic_dim= pic_tensor.unsqueeze_(0)
    load_model.eval()
    with torch.no_grad():
        output= load_model.forward(pic_dim)
    ps= torch.exp(output)
    probs_top = ps.topk(topk)[0]
    index_top = ps.topk(topk)[1]
    probs_top_list = np.array(probs_top)[0]
    index_top_list = np.array(index_top[0])
    class_to_idx= load_model.class_to_idx
    idx_to_class= {x: y for y, x in class_to_idx.items()}
    top_list_classes= []
    for index in index_top_list:
        top_list_classes += [idx_to_class[index]]
    return probs_top_list, top_list_classes

# %%
model_path = 'checkpoint.pth' 
image_path = data_dir + '/test' + '/1/image_06743.jpg'


probs,classes = predict(image_path, model_path, topk=5)

print(probs)
print(classes)
# Out:
# [ 0.01060888  0.01059036  0.01058327  0.01054019  0.01048288]
# ['20', '82', '10', '76', '31']

# %%
# Inputs: paths to saved model and test image
model_path = 'checkpoint.pth'
image_path = data_dir + '/test' + '/20/' + 'image_04912.jpg'

# Other images to try:
# image_path = data_dir + '/test' + '/102/' + 'image_08004.jpg'
# image_path = data_dir + '/test' + '/46/' + 'image_01077.jpg'
# image_path = data_dir + '/test' + '/73/' + 'image_00401.jpg'
# image_path = data_dir + '/test' + '/66/' + 'image_05549.jpg'

# Getting prediction
probs,classes = predict(image_path, model_path, topk=5)

# Uncomment to check if the class of flower (as seen from the file path) matches the top one predicted:
#print(classes[0])

# Converting classes to names
names = []
for i in classes:
    names += [cat_to_name[i]]

# Creating PIL image
image = Image.open(image_path)

# Plotting test image and predicted probabilites
f, ax = plt.subplots(2,figsize = (6,10))

ax[0].imshow(image)
ax[0].set_title(names[0])

y_names = np.arange(len(names))
ax[1].barh(y_names, probs, color='darkblue')
ax[1].set_yticks(y_names)
ax[1].set_yticklabels(names)
ax[1].invert_yaxis() 

plt.show()

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
